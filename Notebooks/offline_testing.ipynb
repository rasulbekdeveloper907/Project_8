# %%
import pandas as pd
from sklearn.ensemble import  RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import joblib

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Rasulbek907\Desktop\Project_8\Data\Feature_Selection\Filtered_Features.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322278 entries, 0 to 322277
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            322278 non-null  int64
#  1   index                 322278 non-null  float64
#  2   dateCrawled           322278 non-null  float64
#  3   name                  322278 non-null  float64
#  4   vehicleType           322278 non-null  float64
#  5   yearOfRegistration    322278 non-null  float64
#  6   model                 322278 non-null  float64
#  7   monthOfRegistration   322278 non-null  float64
#  8   fuelType              322278 non-null  float64
#  9   brand                 322278 non-null  float64
#  10  postalCode            322278 non-null  float64
#  11  lastSeen              322278 non-null  float64
#  12  abtest_control        322278 non-null  float64
#  13  gearbox_automatik     322278 non-null  float64
#  14  notRepairedDamage_ja  322278 non-null  float64
#  15  kilometer_cont        322278 non-null  float64
# dtypes: float64(15), int64(1)
# memory usage: 39.3 MB

# %%
df.head()
# Out:
#    Unnamed: 0     index  dateCrawled      name  vehicleType  \
# 0           0  0.000000     0.584454  0.015422     0.428571
# 1           1  0.000003     0.273117  0.391083     1.000000
# 2           2  0.000005     0.378148  0.332203     0.571429
# 3           3  0.000008     0.823166  0.733871     0.571429
# 4           4  0.000011     0.965794  0.119477     0.857143
#
#    yearOfRegistration     model  monthOfRegistration  fuelType     brand  \
# 0            0.724138  0.475806             0.416667  0.500000  0.025641
# 1            0.482759  0.479839             0.666667  0.500000  0.358974
# 2            0.379310  0.475806             0.500000  0.166667  0.974359
# 3            0.620690  0.415323             0.583333  0.500000  0.794872
# 4            0.172414  0.044355             0.833333  0.166667  0.051282
#
#    postalCode  lastSeen  abtest_control  gearbox_automatik  \
# 0    0.665989  0.972885             0.0                0.0
# 1    0.903792  0.879404             0.0                1.0
# 2    0.909796  0.241615             0.0                0.0
# 3    0.600115  0.933659             0.0                0.0
# 4    0.330614  0.955484             0.0                0.0
#
#    notRepairedDamage_ja  kilometer_cont
# 0                   1.0        0.028770
# 1                   0.0        0.008358
# 2                   0.0        0.010253
# 3                   0.0        0.010961
# 4                   1.0        0.015491

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322278 entries, 0 to 322277
# Data columns (total 15 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   index                 322278 non-null  float64
#  1   dateCrawled           322278 non-null  float64
#  2   name                  322278 non-null  float64
#  3   vehicleType           322278 non-null  float64
#  4   yearOfRegistration    322278 non-null  float64
#  5   model                 322278 non-null  float64
#  6   monthOfRegistration   322278 non-null  float64
#  7   fuelType              322278 non-null  float64
#  8   brand                 322278 non-null  float64
#  9   postalCode            322278 non-null  float64
#  10  lastSeen              322278 non-null  float64
#  11  abtest_control        322278 non-null  float64
#  12  gearbox_automatik     322278 non-null  float64
#  13  notRepairedDamage_ja  322278 non-null  float64
#  14  kilometer_cont        322278 non-null  float64
# dtypes: float64(15)
# memory usage: 36.9 MB

# %%
target = 'kilometer_cont'
X = df.drop(['kilometer_cont', target], axis=1)
y = df[target]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor

preprocessor = StandardScaler()

# Pipeline yaratish
pipeline = Pipeline([
    ('preprocess', preprocessor),
    ('regressor', RandomForestRegressor(random_state=42))
])

# %%
pipeline
# Out:
# Pipeline(steps=[('preprocess', StandardScaler()),
#                 ('regressor', RandomForestRegressor(random_state=42))])

# %%
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('preprocess', StandardScaler()),
#                 ('regressor', RandomForestRegressor(random_state=42))])

# %%
from joblib import dump
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

# Misol uchun pipeline (faqat numerical features uchun)
pipeline = Pipeline([
    ('preprocess', StandardScaler()),
    ('regressor', RandomForestClassifier(random_state=42))
])

# Saqlash yo'li
save_path = r"C:\Users\Rasulbek907\Desktop\Project_MP\Models\Pipeline_Models\RandomForestClassifier.joblib"

# Pipeline'ni saqlash
dump(pipeline, save_path)

print(f"Pipeline muvaffaqiyatli saqlandi: {save_path}")

# %%
from joblib import load
model_path = r"C:\Users\Rasulbek907\Desktop\Project_MP\Models\Pipeline_Models\RandomForestClassifier.joblib"
pipeline = load(model_path)

# %%
X_train = df.drop(columns=['cluster'])
y_train = df['cluster']
pipeline.fit(X_train, y_train)

# %%
import pandas as pd

offline_data = pd.DataFrame({
    'id': [43280],
    'ref': [12345],                  
    'subtitle': [1.0],
    'creatorname': [10.0],
    'totalbytes': [204800],          
    'lastupdated': [44500],          
    'downloadcount': [1500],
    'title': [5.0],
    'tags': [8.0],
    'anomaly': [0.0],
    'download_view_ratio': [0.45],
    'num_tags': [4],
    'title_length': [20],
    'subtitle_length': [50],
    'creator_popularity': [75.0],
    'owner_popularity': [80.0],
    'lastupdated_month': [11],
    'lastupdated_day': [20],
    'lastupdated_weekday': [3]
})

# %%
pred = pipeline.predict(offline_data)
print("Predicted Value:", pred[0])
