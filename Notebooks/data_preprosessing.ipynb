# %%
import pandas as pd
import logging

# Log fayl manzili
log_path = r"C:\Users\Rasulbek907\Desktop\Project_8\Log\data_loader.log"

# Log sozlamalari
logging.basicConfig(
    filename=log_path,
    filemode='a',  # Append mode
    format='%(asctime)s - %(levelname)s - %(message)s',
    level=logging.INFO
)

try:
    logging.info("CSV fayl o'qilmoqda:...")
    df = pd.read_csv(r"C:\Users\Rasulbek907\Desktop\Project_8\Data\Raw_Data\autos.csv")
    logging.info(f"Fayl muvaffaqiyatli o'qildi. Satırlar soni: {len(df)} ustunlar soni: {len(df.columns)}")
except Exception as e:
    logging.error(f"CSV faylni o'qishda xatolik: {e}")

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\Rasulbek907\Desktop\Cars-Kilometer-Prediction-\Data\Raw_Data\filtered.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322278 entries, 0 to 322277
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           322278 non-null  int64
#  1   index                322278 non-null  int64
#  2   dateCrawled          322278 non-null  object
#  3   name                 322278 non-null  object
#  4   seller               322278 non-null  object
#  5   offerType            322278 non-null  object
#  6   price                322278 non-null  int64
#  7   abtest               322278 non-null  object
#  8   vehicleType          322278 non-null  object
#  9   yearOfRegistration   322278 non-null  int64
#  10  gearbox              322278 non-null  object
#  11  powerPS              322278 non-null  int64
#  12  model                322278 non-null  object
#  13  kilometer            322278 non-null  int64
#  14  monthOfRegistration  322278 non-null  int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   index                371528 non-null  int64
#  1   dateCrawled          371528 non-null  object
#  2   name                 371528 non-null  object
#  3   seller               371528 non-null  object
#  4   offerType            371528 non-null  object
#  5   price                371528 non-null  int64
#  6   abtest               371528 non-null  object
#  7   vehicleType          333659 non-null  object
#  8   yearOfRegistration   371528 non-null  int64
#  9   gearbox              351319 non-null  object
#  10  powerPS              371528 non-null  int64
#  11  model                351044 non-null  object
#  12  kilometer            371528 non-null  int64
#  13  monthOfRegistration  371528 non-null  int64
#  14  fuelType             338142 non-null  object
# ...

# %%
missing = df.isna().sum()
missing_percent = (missing / len(df)) * 100
missing_df = pd.DataFrame({'missing_count': missing, 'missing_percent': missing_percent})
print(missing_df.sort_values(by='missing_percent', ascending=False))
# Out:
#                      missing_count  missing_percent
# notRepairedDamage            72060        19.395577
# vehicleType                  37869        10.192771
# fuelType                     33386         8.986133
# model                        20484         5.513447
# gearbox                      20209         5.439429
# offerType                        0         0.000000
# seller                           0         0.000000
# name                             0         0.000000
# dateCrawled                      0         0.000000
# index                            0         0.000000
# abtest                           0         0.000000
# yearOfRegistration               0         0.000000
# price                            0         0.000000
# kilometer                        0         0.000000
# powerPS                          0         0.000000
# monthOfRegistration              0         0.000000
# brand                            0         0.000000
# ...

# %%
df["vehicleType"].unique()
# Out:
# array([nan, 'coupe', 'suv', 'kleinwagen', 'limousine', 'cabrio', 'bus',
#        'kombi', 'andere'], dtype=object)

# %%
df["gearbox"].unique()
# Out:
# array(['manuell', 'automatik', nan], dtype=object)

# %%
df["gearbox"].unique()
# Out:
# array(['manuell', 'automatik', nan], dtype=object)

# %%
df["fuelType"].unique()
# Out:
# array(['benzin', 'diesel', nan, 'lpg', 'andere', 'hybrid', 'cng',
#        'elektro'], dtype=object)

# %%
df["notRepairedDamage"].unique()
# Out:
# array([nan, 'ja', 'nein'], dtype=object)

# %%
columns_to_fill = ['vehicleType', 'gearbox', 'model', 'fuelType', 'notRepairedDamage']

for col in columns_to_fill:
    mode_value = df[col].mode()[0]  
    df[col].fillna(mode_value, inplace=True)
# Out:
# C:\maya_temp\ipykernel_17624\3604203200.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(mode_value, inplace=True)

# %%
df.isna().sum()
# Out:
# index                  0
# dateCrawled            0
# name                   0
# seller                 0
# offerType              0
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dateCreated            0
# nrOfPictures           0
# postalCode             0
# lastSeen               0
# dtype: int64

# %%
import pandas as pd

# Ikkala shart bo'yicha filterlash
filtered_df = df[
    (df["yearOfRegistration"] >= 1990) & (df["yearOfRegistration"] <= 2025) &
    (df["powerPS"] >= 10) & (df["powerPS"] <= 2000)
]

# Natijani ko'rish
print(filtered_df)
# Out:
#          index          dateCrawled  \
# 1            1  2016-03-24 10:58:45
# 2            2  2016-03-14 12:52:21
# 3            3  2016-03-17 16:54:04
# 4            4  2016-03-31 17:25:20
# 5            5  2016-04-04 17:36:23
# ...        ...                  ...
# 371520  371520  2016-03-19 19:53:49
# 371524  371524  2016-03-05 19:56:21
# 371525  371525  2016-03-19 18:57:12
# 371526  371526  2016-03-20 19:41:08
# 371527  371527  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 1                                    A5_Sportback_2.7_Tdi  privat   Angebot
# 2                          Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# ...

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 322278 entries, 1 to 371527
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   index                322278 non-null  int64
#  1   dateCrawled          322278 non-null  object
#  2   name                 322278 non-null  object
#  3   seller               322278 non-null  object
#  4   offerType            322278 non-null  object
#  5   price                322278 non-null  int64
#  6   abtest               322278 non-null  object
#  7   vehicleType          322278 non-null  object
#  8   yearOfRegistration   322278 non-null  int64
#  9   gearbox              322278 non-null  object
#  10  powerPS              322278 non-null  int64
#  11  model                322278 non-null  object
#  12  kilometer            322278 non-null  int64
#  13  monthOfRegistration  322278 non-null  int64
#  14  fuelType             322278 non-null  object
# ...

# %%
df["powerPS"]
# Out:
# 0           0
# 1         190
# 2         163
# 3          75
# 4          69
#          ...
# 371523      0
# 371524    101
# 371525    102
# 371526    100
# 371527    320
# Name: powerPS, Length: 371528, dtype: int64

# %%
import pandas as pd

# Minimal qiymat
min_power = df["notRepairedDamage"].min()

# Maksimal qiymat
max_power = df["notRepairedDamage"].max()

print(f"Minimal notRepairedDamage: {min_power}")
print(f"Maksimal notRepairedDamage: {max_power}")
# Out:
# Minimal notRepairedDamage: ja
# Maksimal notRepairedDamage: nein

# %%
filtered_df.to_csv(r"C:\Users\Rasulbek907\Desktop\Project_8\Data\Raw_Data\filtered.csv")

# %%
df = pd.read_csv(r"C:\Users\Rasulbek907\Desktop\Project_8\Data\Raw_Data\filtered.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322278 entries, 0 to 322277
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           322278 non-null  int64
#  1   index                322278 non-null  int64
#  2   dateCrawled          322278 non-null  object
#  3   name                 322278 non-null  object
#  4   seller               322278 non-null  object
#  5   offerType            322278 non-null  object
#  6   price                322278 non-null  int64
#  7   abtest               322278 non-null  object
#  8   vehicleType          322278 non-null  object
#  9   yearOfRegistration   322278 non-null  int64
#  10  gearbox              322278 non-null  object
#  11  powerPS              322278 non-null  int64
#  12  model                322278 non-null  object
#  13  kilometer            322278 non-null  int64
#  14  monthOfRegistration  322278 non-null  int64
# ...

# %%
import sys
import os

# Scripts papkasini yo'lga qo'shamiz
source_path = r"C:\Users\Rasulbek907\Desktop\Project_8\Scripts"
if source_path not in sys.path:
    sys.path.append(source_path)

print("Python executable:", sys.executable)
print("Scripts path added:", source_path)

# Endi modulni import qilamiz
from data_preprosessing import MissingValueImputer, Encoder, Scaler
# Out:
# Python executable: c:\Users\Rasulbek907\Desktop\Project_8\mpvenv\Scripts\python.exe
# Scripts path added: C:\Users\Rasulbek907\Desktop\Project_8\Scripts

# %%
imputer = MissingValueImputer(df).fill()
df = imputer.get_df()
# Out:
# C:\Users\Rasulbek907\Desktop\Project_8\Scripts\data_preprosessing.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(mode_value, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322278 entries, 0 to 322277
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           322278 non-null  int64
#  1   index                322278 non-null  int64
#  2   dateCrawled          322278 non-null  object
#  3   name                 322278 non-null  object
#  4   seller               322278 non-null  object
#  5   offerType            322278 non-null  object
#  6   price                322278 non-null  int64
#  7   abtest               322278 non-null  object
#  8   vehicleType          322278 non-null  object
#  9   yearOfRegistration   322278 non-null  int64
#  10  gearbox              322278 non-null  object
#  11  powerPS              322278 non-null  int64
#  12  model                322278 non-null  object
#  13  kilometer            322278 non-null  int64
#  14  monthOfRegistration  322278 non-null  int64
# ...

# %%
encoder = Encoder(df).encodla()
df = encoder.get_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322278 entries, 0 to 322277
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unnamed: 0              322278 non-null  int64
#  1   index                   322278 non-null  int64
#  2   dateCrawled             322278 non-null  int64
#  3   name                    322278 non-null  int64
#  4   price                   322278 non-null  int64
#  5   vehicleType             322278 non-null  int64
#  6   yearOfRegistration      322278 non-null  int64
#  7   powerPS                 322278 non-null  int64
#  8   model                   322278 non-null  int64
#  9   kilometer               322278 non-null  int64
#  10  monthOfRegistration     322278 non-null  int64
#  11  fuelType                322278 non-null  int64
#  12  brand                   322278 non-null  int64
#  13  dateCreated             322278 non-null  int64
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
scaler = MinMaxScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])
print(df.head())
# Out:
#    Unnamed: 0     index  dateCrawled      name         price  vehicleType  \
# 0    0.000000  0.000000     0.584454  0.015422  8.521602e-06     0.428571
# 1    0.000003  0.000003     0.273117  0.391083  4.563481e-06     1.000000
# 2    0.000005  0.000005     0.378148  0.332203  6.984919e-07     0.571429
# 3    0.000008  0.000008     0.823166  0.733871  1.676381e-06     0.571429
# 4    0.000011  0.000011     0.965794  0.119477  3.026798e-07     0.857143
#
#    yearOfRegistration   powerPS     model  kilometer  ...  seller_gewerblich  \
# 0            0.724138  0.090452  0.475806   0.827586  ...                0.0
# 1            0.482759  0.076884  0.479839   0.827586  ...                0.0
# 2            0.379310  0.032663  0.475806   1.000000  ...                0.0
# 3            0.620690  0.029648  0.415323   0.586207  ...                0.0
# 4            0.172414  0.046231  0.044355   1.000000  ...                0.0
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0     index  dateCrawled      name         price  vehicleType  \
# 0    0.000000  0.000000     0.584454  0.015422  8.521602e-06     0.428571
# 1    0.000003  0.000003     0.273117  0.391083  4.563481e-06     1.000000
# 2    0.000005  0.000005     0.378148  0.332203  6.984919e-07     0.571429
# 3    0.000008  0.000008     0.823166  0.733871  1.676381e-06     0.571429
# 4    0.000011  0.000011     0.965794  0.119477  3.026798e-07     0.857143
#
#    yearOfRegistration   powerPS     model  kilometer  ...  seller_gewerblich  \
# 0            0.724138  0.090452  0.475806   0.827586  ...                0.0
# 1            0.482759  0.076884  0.479839   0.827586  ...                0.0
# 2            0.379310  0.032663  0.475806   1.000000  ...                0.0
# 3            0.620690  0.029648  0.415323   0.586207  ...                0.0
# 4            0.172414  0.046231  0.044355   1.000000  ...                0.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322278 entries, 0 to 322277
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unnamed: 0              322278 non-null  float64
#  1   index                   322278 non-null  float64
#  2   dateCrawled             322278 non-null  float64
#  3   name                    322278 non-null  float64
#  4   price                   322278 non-null  float64
#  5   vehicleType             322278 non-null  float64
#  6   yearOfRegistration      322278 non-null  float64
#  7   powerPS                 322278 non-null  float64
#  8   model                   322278 non-null  float64
#  9   kilometer               322278 non-null  float64
#  10  monthOfRegistration     322278 non-null  float64
#  11  fuelType                322278 non-null  float64
#  12  brand                   322278 non-null  float64
# ...

# %%
df.to_csv(r"C:\Users\Rasulbek907\Desktop\Project_8\Data\Preprocessing\Preprosessed.csv")

# %%
from IPython.display import display, HTML

display(HTML("""
<a href="file:///C:/Users/Rasulbek907/Desktop/Project_8/Data/Preprocessing/Preprosessed.csv" target="_blank" style="
    display: inline-block;
    padding: 10px 20px;
    font-size: 16px;
    color: white;
    background-color: #2196F3;
    text-align: center;
    text-decoration: none;
    border-radius: 5px;
">
Open Preprocessed CSV
</a>
"""))
# Out:
# <a href="file:///C:/Users/Rasulbek907/Desktop/Project_8/Data/Preprocessing/Preprosessed.csv" target="_blank" style="
#     display: inline-block;
#     padding: 10px 20px;
#     font-size: 16px;
#     color: white;
#     background-color: #2196F3;
#     text-align: center;
#     text-decoration: none;
#     border-radius: 5px;
# ">
# Open Preprocessed CSV
# </a>

# %%
from IPython.display import display, HTML

# Clickable link (button ko‘rinishida)
display(HTML("""
<a href="feature_analysis.ipynb" target="_self" style="
    display: inline-block;
    padding: 10px 20px;
    font-size: 16px;
    color: white;
    background-color: #4CAF50;
    text-align: center;
    text-decoration: none;
    border-radius: 5px;
">
Next Step
</a>
"""))
# Out:
# <a href="feature_analysis.ipynb" target="_self" style="
#     display: inline-block;
#     padding: 10px 20px;
#     font-size: 16px;
#     color: white;
#     background-color: #4CAF50;
#     text-align: center;
#     text-decoration: none;
#     border-radius: 5px;
# ">
# Next Step
# </a>
