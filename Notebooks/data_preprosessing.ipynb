# %%
import pandas as pd
import logging

# Log fayl manzili
log_path = r"C:\Users\Rasulbek907\Desktop\Project_9\Log\data_loader.log"

# Log sozlamalari
logging.basicConfig(
    filename=log_path,
    filemode='a',  # Append mode
    format='%(asctime)s - %(levelname)s - %(message)s',
    level=logging.INFO
)

try:
    logging.info("CSV fayl o'qilmoqda:...")
    df = pd.read_csv(r"C:\Users\Rasulbek907\Desktop\Project_9\Data\Raw_Data\autos.csv")
    logging.info(f"Fayl muvaffaqiyatli o'qildi. Satırlar soni: {len(df)} ustunlar soni: {len(df.columns)}")
except Exception as e:
    logging.error(f"CSV faylni o'qishda xatolik: {e}")

# %%
import sys
import os

# Scripts papkasini yo'lga qo'shamiz
source_path = r"C:\Users\Rasulbek907\Desktop\Project_9\Scripts"
if source_path not in sys.path:
    sys.path.append(source_path)

print("Python executable:", sys.executable)
print("Scripts path added:", source_path)

# Endi modulni import qilamiz
from data_preprosessing import MissingValueImputer, Encoder, Scaler
# Out:
# Python executable: c:\Users\Rasulbek907\Desktop\Project_9\mpvenv\Scripts\python.exe
# Scripts path added: C:\Users\Rasulbek907\Desktop\Project_9\Scripts

# %%
target_col = 'kilometer'
imputer = MissingValueImputer(df, target_col=target_col).fill()
df = imputer.get_df()
# Out:
# C:\Users\Rasulbek907\Desktop\Project_9\Scripts\data_preprosessing.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(mode_value, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   index                371528 non-null  int64
#  1   dateCrawled          371528 non-null  object
#  2   name                 371528 non-null  object
#  3   seller               371528 non-null  object
#  4   offerType            371528 non-null  object
#  5   price                371528 non-null  int64
#  6   abtest               371528 non-null  object
#  7   vehicleType          371528 non-null  object
#  8   yearOfRegistration   371528 non-null  int64
#  9   gearbox              371528 non-null  object
#  10  powerPS              371528 non-null  int64
#  11  model                371528 non-null  object
#  12  kilometer            371528 non-null  int64
#  13  monthOfRegistration  371528 non-null  int64
#  14  fuelType             371528 non-null  object
# ...

# %%
target_col = 'kilometer'
encoder = Encoder(df).encodla()
df = encoder.get_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   index                   371528 non-null  int64
#  1   dateCrawled             371528 non-null  int64
#  2   name                    371528 non-null  int64
#  3   price                   371528 non-null  int64
#  4   vehicleType             371528 non-null  int64
#  5   yearOfRegistration      371528 non-null  int64
#  6   powerPS                 371528 non-null  int64
#  7   model                   371528 non-null  int64
#  8   kilometer               371528 non-null  int64
#  9   monthOfRegistration     371528 non-null  int64
#  10  fuelType                371528 non-null  int64
#  11  brand                   371528 non-null  int64
#  12  dateCreated             371528 non-null  int64
#  13  nrOfPictures            371528 non-null  int64
# ...

# %%
target_col = 'kilometer'
scaler = Scaler(df, target_col=target_col).scaling_qil()
df = scaler.get_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   index                   371528 non-null  float64
#  1   dateCrawled             371528 non-null  float64
#  2   name                    371528 non-null  float64
#  3   price                   371528 non-null  float64
#  4   vehicleType             371528 non-null  float64
#  5   yearOfRegistration      371528 non-null  float64
#  6   powerPS                 371528 non-null  float64
#  7   model                   371528 non-null  float64
#  8   kilometer               371528 non-null  int64
#  9   monthOfRegistration     371528 non-null  float64
#  10  fuelType                371528 non-null  float64
#  11  brand                   371528 non-null  float64
#  12  dateCreated             371528 non-null  float64
# ...

# %%
df.to_csv(r"C:\Users\Rasulbek907\Desktop\Project_9\Data\Preprosessed\Preprosessed_Simple.csv")
